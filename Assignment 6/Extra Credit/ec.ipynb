# %% [markdown]
# <a href="https://colab.research.google.com/github/ashaaher/Emerging-Technologies/blob/master/Assignment%206/Extra%20Credit/ec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tensorflow/tfx ~/tfx-source && pushd ~/tfx-source
# Out:
# Cloning into '/root/tfx-source'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 31787 (delta 3), reused 1 (delta 0), pack-reused 31780
# Receiving objects: 100% (31787/31787), 181.53 MiB | 31.64 MiB/s, done.
# Resolving deltas: 100% (23921/23921), done.
# ~/tfx-source /content

# %%
cp -r ~/tfx-source/tfx/examples/cifar10 ~/

# %%
# The following is needed until tensorflow-model-analysis 0.23.0 is released
# !pip uinstall tensorflow-model-analysis
# !pip install git+https://github.com/tensorflow/model-analysis.git#egg=tensorflow_model_analysis
# Out:
# ERROR: cifar10/ is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with svn+, git+, hg+, or bzr+).
# ERROR: unknown command "uinstall" - maybe you meant "uninstall"
# ...
#   Cloning https://github.com/tensorflow/model-analysis.git to /tmp/pip-install-spdorqnt/tensorflow-model-analysis
#   Running command git clone -q https://github.com/tensorflow/model-analysis.git /tmp/pip-install-spdorqnt/tensorflow-model-analysis
# ...
#      |████████████████████████████████| 8.7MB 7.3MB/s
# ...
#      |████████████████████████████████| 788kB 43.4MB/s
# ...
#      |████████████████████████████████| 63.8MB 83kB/s
# ...
#      |████████████████████████████████| 2.2MB 43.6MB/s
# ...
#      |████████████████████████████████| 51kB 7.6MB/s
# ...
#      |████████████████████████████████| 61kB 8.0MB/s
# ...
#      |████████████████████████████████| 61kB 8.3MB/s
# ...
#      |████████████████████████████████| 2.0MB 40.3MB/s
# ...
#      |████████████████████████████████| 153kB 16.6MB/s
# ...

# %%
# !pip install cifar10/

# %%
 import tensorflow_datasets as tfds ds = tfds.load('cifar10', data_dir='./cifar10/data/',split=['train', 'test'])
